# %%
import xarray as xr
import numpy as np
import pandas as pd

# %%
ds = xr.open_dataset('/home/fabio/src/buceo_avances123_es/content/post/incremento_temperatura_mar/METOFFICE-GLO-SST-L4-NRT-OBS-ANOM-V2_1673389569263.nc')

# %%
temp = ds['analysed_sst']
temp.plot()
